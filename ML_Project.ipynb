# %%
import pandas as pd
data=pd.read_csv("taxi.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 data=pd.read_csv("taxi.csv")
#       3 data.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
x=data.drop("Numberofweeklyriders",axis=1)
y=data["Numberofweeklyriders"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_text,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0  )

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
print("Training score:",model.score(x_train,y_train))
# Out:
# Training score: 0.934798170718289

# %%
import pickle
pickle.dump(model, open("model.pkl", "wb"))

# %%
model1=pickle.load(open("model.pkl", "rb"))

# %%
print(model.predict([[40,1700000,10570,80]]))
# Out:
# [166095.67586185]
# c:\Users\yuvaraj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
